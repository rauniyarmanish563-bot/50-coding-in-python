# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/check%20eligible%20for%20voting%20or%20not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check voting eligibility (different method)
def check_vote(age):
    # Using ternary operator
    result = "Eligible to vote" if age >= 18 else "Not Eligible to vote"

    # Print inside function
    print(result)

# Taking input
age = int(input("Enter age: "))

# Function call
check_vote(age)
# Out:
# Enter age: 20
# Eligible to vote
