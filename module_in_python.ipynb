# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/module_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numericcalculation import addnumbers , calculateproduct
m=10
n=20
print("sum of",m,"and",n,"is:",addnumbers(m,n))
print("product of",m,"and",n,"is:",calculateproduct(m,n))
