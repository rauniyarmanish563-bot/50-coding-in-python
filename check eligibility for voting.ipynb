# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/check%20eligibility%20for%20voting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check eligibility
def check_vote_eligibility(age):
    if age >= 18:
        return "Eligible"
    else:
        return "Not Eligible"

# Taking input from user
age = int(input("Enter age: "))

# Calling function and printing result
result = check_vote_eligibility(age)
print(result)
# Out:
# Enter age: 35
# Eligible
