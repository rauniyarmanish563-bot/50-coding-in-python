# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/check%20eligibility%20for%20voting%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check eligibility for voting
def is_eligible(age):
    return age >= 18

# Input
age = int(input("Enter age: "))

# Using function result
if is_eligible(age):
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age: 27
# Eligible
