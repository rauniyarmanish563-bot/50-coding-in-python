# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/module%20in%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numericcalculation
m=10
n=20
print("sum of",m,"and",n,"is:",numericcalculation.addnumber(m,n))
print("product of",m,"and",n,"is:",numericcalculation.calculateproduct(m,n))

# %%
from numericcalculation import*
m=10
n=20
print("sum of",m,"and",n,"is",addnumbers(m,n))
print("product of",m,"and",n,"is:",calculateproduct(m,n))
