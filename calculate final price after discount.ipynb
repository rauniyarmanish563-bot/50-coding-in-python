# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/calculate%20final%20price%20after%20discount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to calculate final price after discount
def final_bill(price, discount):
    discount_amount = (price * discount) / 100
    final_price = price - discount_amount
    return final_price

# Input
price = float(input("Enter price: "))
discount = float(input("Enter discount (%): "))

# Function call
result = final_bill(price, discount)

# Output
print("Final price after discount =", result)
# Out:
# Enter price: 300
# Enter discount (%): 3
# Final price after discount = 291.0
