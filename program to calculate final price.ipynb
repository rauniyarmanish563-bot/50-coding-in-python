# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/program%20to%20calculate%20final%20price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Recursive function to calculate final price
def final_price(price, discount):
    if discount == 0:
        return price
    return final_price(price - (price / 100), discount - 1)

# Input
p = float(input("Enter price: "))
d = int(input("Enter discount (%): "))

# Output
print("Final price after discount =", final_price(p, d))
# Out:
# Enter price: 4999
# Enter discount (%): 20
# Final price after discount = 4088.716781048556
