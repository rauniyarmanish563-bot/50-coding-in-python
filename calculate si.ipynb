# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/calculate%20si.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function with default values
def simple_interest(p=0, r=0, t=0):
    si = (p * r * t) / 100
    return si

# Input
p = float(input("Enter Principal: "))
r = float(input("Enter Rate: "))
t = float(input("Enter Time: "))

# Function call
result = simple_interest(p, r, t)

# Output
print("Simple Interest =", result)
# Out:
# Enter Principal: 100000
# Enter Rate: 22
# Enter Time: 2
# Simple Interest = 44000.0
