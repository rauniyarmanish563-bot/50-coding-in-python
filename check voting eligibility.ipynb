# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/check%20voting%20eligibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check voting eligibility
def vote_check():
    age = int(input("Enter age: "))

    if age < 18:
        print("Not Eligible")
    else:
        print("Eligible")

# Function call
vote_check()
# Out:
# Enter age: 22
# Eligible
