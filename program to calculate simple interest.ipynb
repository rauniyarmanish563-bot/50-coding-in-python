# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/program%20to%20calculate%20simple%20interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Class to calculate simple interest
class Interest:

    def __init__(self, p, r, t):
        self.p = p
        self.r = r
        self.t = t

    def calculate(self):
        return (self.p * self.r * self.t) / 100

# Input
p = float(input("Enter Principal: "))
r = float(input("Enter Rate: "))
t = float(input("Enter Time: "))

# Object creation
obj = Interest(p, r, t)

# Output
print("Simple Interest =", obj.calculate())
# Out:
# Enter Principal: 50000
# Enter Rate: 10
# Enter Time: 2
# Simple Interest = 10000.0
