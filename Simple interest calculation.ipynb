# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/50-coding-in-python/blob/main/Simple%20interest%20calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to calculate simple interest
def simple_interest(p, r, t):
    si = (p * r * t) / 100
    print("Simple Interest is:", si)

# Taking input from user
p = float(input("Enter Principal (P): "))
r = float(input("Enter Rate (R): "))
t = float(input("Enter Time (T): "))

# Function call
simple_interest(p, r, t)
# Out:
# Enter Principal (P): 20000
# Enter Rate (R): 6
# Enter Time (T): 3
# Simple Interest is: 3600.0
